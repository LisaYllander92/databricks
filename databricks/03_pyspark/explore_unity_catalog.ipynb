-- %% [markdown]
-- ## Explore catalog-schema-volumes

-- %%
%sql
SHOW CATALOGS;

-- %%
%sql
SHOW SCHEMAS IN data;

-- %% [markdown]
-- Multible cells in same block -> shift + ctrl + enter -> to run one cell

-- %%
SHOW VOLUMES IN data.olympic_games;

LIST '/Volumes/data/olympic_games/raw_data';

-- %%
%python
volume_path = '/Volumes/data/olympic_games/raw_data'

files_in_volume = spark.sql(f"LIST '{volume_path}';")
#files_in_volume #lazy evaluation, we see schema not actual data
files_in_volume.display()
#display(files_in_volume)

-- %%
%python
_sqldf.display()
